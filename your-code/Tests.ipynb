# %%
from IPython.display import display, Image

def decisions():
    decision = input("Do you want to play the game? (write yes or no)").lower().strip()
    if decision == "yes":
        print("Lets the game start")
        display(Image(filename='C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture.png'))
    elif decision == "no":
        decision_2 = input("Are you sure that you do not want to play? (write yes or no)").lower().strip()
        if decision_2 == "yes":
            print("Bye Bye! Have a nice day")
            display(Image(filename='C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture1.png'))
            import sys 
            sys.exit()
        
        else:
            print("Ok let the game start!")
            display(Image(filename='C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture.png'))
    else:
        print("Please reply yes or no.")
        decisions()
    
decisions()
# Out:
# Do you want to play the game? (write yes or no)no
# Are you sure that you do not want to play? (write yes or no)yes
# Bye Bye! Have a nice day
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from IPython.display import display, Image
display(Image(filename='C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture.png'))

# %%
from IPython.display import display, Image
Image('C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture1.png')

# %%
display(Image(filename='C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\Capture3.jpeg'))

# %%
import os
import openpyxl
import pandas as pd
from openpyxl.utils.dataframe import dataframe_to_rows

def name_of_user():
    name = input("Please write your name:").capitalize().strip()
    #print(name)
    
    if name.isalpha() == False:
        print("Your name has numbers, I dont think so!")
        name_of_user()    
    else:

        file_name = 'C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.xlsx'

        name_data = pd.DataFrame({name})

        # create excel file
        if os.path.isfile(file_name):  # if file already exists append to existing file
            workbook = openpyxl.load_workbook(file_name)  # load workbook if already exists
            sheet = workbook['file_name']  # declare the active sheet 

            # append the dataframe results to the current excel file
            for row in dataframe_to_rows(name_data, header = False, index = False):
                sheet.append(row)
            workbook.save(file_name)  # save workbook
            workbook.close()  # close workbook
        else:  # create the excel file if doesn't already exist
            with pd.ExcelWriter(path = file_name, engine = 'openpyxl') as writer:
                name_data.to_excel(writer, index = False, sheet_name = 'file_name')
        
        
name_of_user()
# Out:
# Please write your name:nuno

# %%
import os
import openpyxl
import pandas as pd
from openpyxl.utils.dataframe import dataframe_to_rows

file_name = 'C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.xlsx'

name_data = pd.DataFrame({name})

# create excel file
if os.path.isfile(file_name):  # if file already exists append to existing file
    workbook = openpyxl.load_workbook(file_name)  # load workbook if already exists
    sheet = workbook['file_name']  # declare the active sheet 

    # append the dataframe results to the current excel file
    for row in dataframe_to_rows(name_data, header = False, index = False):
        sheet.append(row)
    workbook.save(file_name)  # save workbook
    workbook.close()  # close workbook
else:  # create the excel file if doesn't already exist
    with pd.ExcelWriter(path = file_name, engine = 'openpyxl') as writer:
        name_data.to_excel(writer, index = False, sheet_name = 'file_name')

# %%
from IPython.display import Audio
sound_file = 'C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\Queen - We are the champions (Chorus only).mp3'
display(Audio(sound_file, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
import pandas as pd

def name_of_user():
    name = input("Please write your name:").capitalize().strip()
    age = input("Please write your age:").strip()
    print(name, age)
    
    dict = {}
    dict["Name"] = name
    dict["Age"] = age
    print(dict)
    
    list_of_dict = list(dict.items())
    print(list_of_dict)
    
    df = pd.DataFrame(list_of_dict)
    print(df)  
    
    
    
    try:
        df.to_csv()
    except:
        df = df.to_csv
        df.append(dict)
        
    
    if os.path.isfile(df):
        df = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.csv")
        df.append(dict)
        df = df.to_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.csv")
    else:
        df = df.to_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.csv")
        df.append(dict)

name_of_user()
# Out:
# Please write your name:beatriz
# Please write your age:27
# Beatriz 27
# {'Name': 'Beatriz', 'Age': '27'}
# [('Name', 'Beatriz'), ('Age', '27')]
#       0        1
# 0  Name  Beatriz
# 1   Age       27
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1004/2748209574.py in <module>
#      26         df.append(dict)
#      27
# ---> 28 name_of_user()
#
# ~\AppData\Local\Temp/ipykernel_1004/2748209574.py in name_of_user()
#      18     print(df)
#      19
# ---> 20     if os.path.isfile(df):
#      21         df = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Project Espace Room Python Game\\NamesGame.csv")
#      22         df.append(dict)
#
# c:\users\beatr\appdata\local\programs\python\python39\lib\genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ...

# %%
        name_data = pd.DataFrame({name})

        # create excel file
        if os.path.isfile(file_name):  # if file already exists append to existing file
            workbook = openpyxl.load_workbook(file_name)  # load workbook if already exists
            sheet = workbook['file_name']  # declare the active sheet 

            # append the dataframe results to the current excel file
            for row in dataframe_to_rows(name_data, header = False, index = False):
                sheet.append(row)
            workbook.save(file_name)  # save workbook
            workbook.close()  # close workbook
        else:  # create the excel file if doesn't already exist
            with pd.ExcelWriter(path = file_name, engine = 'openpyxl') as writer:
                name_data.to_excel(writer, index = False, sheet_name = 'file_name')
